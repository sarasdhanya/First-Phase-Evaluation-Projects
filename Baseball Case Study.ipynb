# %% [markdown]
# # Baseball Case Study

# %% [markdown]
# Project Description
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
# -- Input features-
# 1.	W - This indicates the number of Wins credited to a pitcher: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
# 2.	R - This indicates Runs scored. A run is scored when a player advances around first, second and third base and returns safely to home plate, touching the bases in that order, before three outs are recorded and all obligations to reach base safely on batted balls are met or assured: number of times a player crosses home plate.
# 3.	AB - This means At bat or time at bat. It's is a batter's turn batting against a pitcher: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction.
# 4.	H - This means Hit. It's also called a "base hit", is credited to a batter when the batter safely reaches or passes first base after hitting the ball into fair territory, without the benefit of either an error or a fielder's choice: reaching base because of a batted, fair ball without error by the defense.
# 5.	2B - This means the act of a batter striking the pitched ball and safely reaching second base without being called out by the umpire, without the benefit of a fielder's misplay (see error) or another runner being put out on a fielder's choice. A double is a type of hit (the others being the single, triple and home run) and is sometimes called a "two-bagger" or "two-base hit": hits on which the batter reaches second base safely without the contribution of a fielding error.
# 6.	3B - This measns a Triple.It's is the act of a batter safely reaching third base after hitting the ball, with neither the benefit of a fielder's misplay nor another runner being put out on a fielder's choice. A triple is sometimes called a "three-bagger" or "three-base hit": hits on which the batter reaches third base safely without the contribution of a fielding error.
# 7.	HR - This means Home runs. It's scored when the ball is hit in such a way that the batter is able to circle the bases and reach home plate safely in one play without any errors being committed by the defensive team. A home run is usually achieved by hitting the ball over the outfield fence between the foul poles (or hitting either foul pole) without the ball touching the field: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
# 8.	BB - This means Base on balls (also called a "walk"). It occurs in baseball when a batter receives four pitches that the umpire calls balls, and is in turn awarded first base without the possibility of being called out: hitter not swinging at four pitches called out of the strike zone and awarded first base.
# 9.	SO - Also denoted as "K" means Strikeout. It occurs when a batter accumulates three strikes during a time at bat. It usually means that the batter is out: number of batters who received strike three.
# 10.	SB - This means Stolen base. It occurs when a runner advances to a base to which they are not entitled and the official scorer rules that the advance should be credited to the action of the runner: number of bases advanced by the runner while the ball is in the possession of the defense.
# 11.	RA - This means Run Average. It refer to measures of the rate at which runs are allowed or scored.
# 12.	ER - This means Earned run. It refers to any run that was fully enabled by the offensive team's production in the face of competent play from the defensive team: number of runs that did not occur as a result of errors or passed balls.
# 13.	ERA - This means Earned Run Average. It refers to the average of earned runs allowed by a pitcher per nine innings pitched (i.e. the traditional length of a game). It is determined by dividing the number of earned runs allowed by the number of innings pitched and multiplying by nine: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
# 14.	CG - This means Complete Game. It's the act of a pitcher pitching an entire game without the benefit of a relief pitcher. A pitcher who meets this criterion will be credited with a complete game regardless of the number of innings played: number of games where player was the only pitcher for their team.
# 15.	SHO - This means Shutout. It refers to the act by which a single pitcher pitches a complete game and does not allow the opposing team to score a run: number of complete games pitched with no runs allowed.
# 16.	SV - This means Save. It's credited to a pitcher who finishes a game for the winning team under certain prescribed circumstances: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
# 17.	E - This means Errors. It's an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out. The term error is sometimes used to refer to the play during which an error was committed: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result.
#
# -- Output: Number of predicted wins (W)
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics

# %% [markdown]
# # Importing requried Libraries:

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing the dataset:

# %%
df=pd.read_csv("baseball.csv")
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# # Identifing type of problem:

# %%
#Checking the data type of each attribute
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# As per problem statement Target variable i.e. W is int64 i.e. continuous value so we Regression to learn our model.

# %% [markdown]
# # Exploratory Data Analysis:

# %%
#Checking shape of dataset
df.shape
# Out:
# (30, 17)

# %%
#Checking the data types of all columns
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# ERA is a float type data and except ERA all columns are int type data.

# %%
#Checking the information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
#  there is a(1)float64 vallue and (16)int value and there are no null values.

# %%
#Checking unique values of each columns
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %% [markdown]
# So, I can see these are number of unique values in each column.

# %%
#Checking null values in dataset
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# No missing values are present in the given dataset.

# %%
#Checking for null values in heat map
plt.figure(figsize=[10,8])
sns.heatmap(df.isnull())
plt.title('Null Values')
plt.show()

# %% [markdown]
# I can see in graph that there is no null values in the given dataset.

# %%
#Checking value counts of target column
df['W'].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %% [markdown]
# I can see there are no missing values or spaaces in the target column.

# %%
#Checking description of dataset
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# I can observe that all the columns have the count value of 30 there are no negative values and Few columns have very low values in it, where few have very low values in it, where few have very high values in the datset.

# %% [markdown]
# # Data Visualization:

# %% [markdown]
# # Univariate Analysis:

# %%
plt.figure(figsize = (25,50), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=17:
        ax = plt.subplot(10,2,plotnumber)
        sns.distplot(df[column], color = 'skyblue')
        plt.xlabel(column,fontsize=20)
        
    plotnumber +=1
plt.show()

# %% [markdown]
# Almost all the columns are normally distributed.Except R,SO,CG and E.

# %%
plt.figure(figsize = (25,50), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=17:
        ax = plt.subplot(10,2,plotnumber)
        sns.histplot(df[column], color = 'skyblue')
        plt.xlabel(column,fontsize=20)
        
    plotnumber += 1
plt.show()

# %%
plt.figure(figsize = (25,50), facecolor = 'white')
plotnumber = 1
for column in df:
    if plotnumber <=17:
        ax = plt.subplot(10,2,plotnumber)
        sns.boxplot(df[column], color = 'skyblue')
        plt.xlabel(column,fontsize=20)
        
    plotnumber +=1
plt.show()

# %% [markdown]
# As shown in boxplot R,ERA,SHO,SV and E input variable is having outliers in it. So,we need remove outliers from that the input variables.

# %% [markdown]
# # Bivariate Analysis:

# %%
plt.figure(figsize = (25,50), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=20:
        ax = plt.subplot(7,4,plotnumber)
        plt.scatter(df[column],df['W'], color='b')
        plt.xlabel(column,fontsize=26)
        plt.ylabel('W', fontsize=26)
    plotnumber += 1
plt.tight_layout()

# %% [markdown]
# As, we can see in plot SV,ERA,SHO and R is having almost linear relationship with target variable and other variables are having non linear relation ship with target variable.

# %%
plt.figure(figsize = (25,20), facecolor = 'white')
plotnumber = 1

for column in df:
    if plotnumber <=20:
        plt.figure(figsize = (10,6))
        sns.regplot(df[column], df['W'])
        plt.title('Scatter Plot for Wins vs other attributes')
        plt.xlabel(column)
        plt.ylabel('W')
        
plt.tight_layout()

# %% [markdown]
# RA,ER,ERA have good relation with Win. Reset all the Columns does not good Relation with Win because data is scatter across all the places.

# %% [markdown]
# # Multivariate Analysis:

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# Above the pair plots of each pair of features. I can observe whether they are making good correlation or if they are just scattered with out any pattern.

# %% [markdown]
# # Heatmap:

# %%
plt.figure(figsize = [20, 15])
sns.heatmap(df.corr(), annot = True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# In this chart it is showing. it is lightly correlated with each other but RA,ER,ERA columns are highly correlated with each other. Also These columns are highly negatively correlated with Wins(W) columns that means there is high impact of these columns on wining. We are dropping two columns(er,ra) and keeping ERA from them because these have same kind of effect on wins, will not affect the prediction model.

# %%
plt.figure(figsize =(25, 10))
df.corr()['W'].sort_values(ascending = False).drop(['W']).plot(kind ='bar', color ='skyblue')
plt.xlabel('Features')
plt.ylabel('Column with target names')
plt.title('Correlation')
plt.show()

# %% [markdown]
# As we can see from the correlation matrix and the graph,ER,RA,ERA have the strongest correlation with wins but in negative nature.
#
# In positive side SV has the highest correlation of 0.67 followed by BB,SHO,R,2B all above 0.4.
#
# Even though ER,RA and ERA are very negatively correlated with wins but they showed highest correlation amongst themselves of over 0.99.

# %% [markdown]
# # Data Cleaning:

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# I can see there are no null values.

# %% [markdown]
# # Checking for Outliers:

# %%
df.plot(kind='box',fontsize=15,figsize=(25,25),color='b')
# Out:
# <AxesSubplot:>

# %% [markdown]
# By observing the box plot i can say that there are outliers are R-Runs,ERA-Earned Run average,SHO-Shutout,SV-Saves,E-Errors.

# %% [markdown]
# # Removing Outliers:

# %% [markdown]
# # Zscore method:

# %%
#Features having outliers
features=df[['R','ERA','SHO','SV','E']]

# %%
from scipy.stats import zscore
z=np.abs(zscore(features))
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %% [markdown]
# So,I have removed outliers by using Zscore.

# %%
#Checking shape of new dataset
df_new.shape
# Out:
# (29, 17)

# %% [markdown]
# There are 29 rows and 17 columns of shape of new dataset after removing outliers.

# %%
#Checking shape of old dataset
df.shape
# Out:
# (30, 17)

# %% [markdown]
# There are 30 rows and 17 columns in old datase.

# %%
#Checking dataloss
Dataloss = (((30-29)/30)*100)

# %%
Dataloss
# Out:
# 3.3333333333333335

# %% [markdown]
# So, I can see dataloss in zscore method after removing outliers of 3.33% which is less than 10%

# %% [markdown]
# # Checking for Skewness:

# %%
#Checking for Skewness
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# I can see that there is skewness in Hits(H),Completed games(CG),Shoutouts(SHO),Saves(SV),Errors(E).

# %% [markdown]
# # Removing Skewness:

# %%
#list of skewed features
skew_features=["H","CG","SHO","SV","E"]

# %%
#Removing skewness in H using log1p
df_new["H"]=np.log1p(df_new["H"])

# %%
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
'''
parameters:
method = 'box_cox' or 'yeo-johnson'
'''
# Out:
# "\nparameters:\nmethod = 'box_cox' or 'yeo-johnson'\n"

# %% [markdown]
# I have removed the skewness in E by using yeo-johnson method.

# %%
#Removing skewness using yeo-johnson
df_new[['E','SHO','SV','CG']] = scaler.fit_transform(df_new[['E','SHO','SV','CG']].values)

# %%
#Checking skewness after removing skewness
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.738455
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %% [markdown]
# After trying to remove skewness in H using yeo-johnson method i got 0.0 skewness.

# %%
#After removing let's check how the data has been distributed in each column of skew_features.

plt.figure(figsize=(20,25), facecolor='white')
plotnumber = 1

for column in df_new[skew_features]:
    if plotnumber<=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df_new[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# By seeing the plot i can say that skewness is removed.

# %% [markdown]
# # Splitting the columns:

# %%
x = df_new.drop("W",axis=1)
y = df_new["W"]

# %% [markdown]
# x=Feature and y=Target

# %% [markdown]
# # Scaling Data using StandardScaler:

# %%
#Importing necessary libraries
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
ssc=StandardScaler()
X = pd.DataFrame(ssc.fit_transform(x), columns=x.columns)

# %%
X.head()
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.959398  0.830084  1.723726  1.556538  1.010845 -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.949846  0.201171  1.208917 -0.181389 -0.495021
# 2 -0.274666 -1.100253 -0.088700  1.733325 -0.276617 -0.697101  1.252941
# 3 -1.329231  0.233951 -0.347747 -0.800621 -0.474688 -0.869006 -1.145857
# 4  0.174084  1.255894  2.030708  0.908319  1.704094 -0.353293 -0.197495
#
#          SO        SB        RA        ER       ERA        CG       SHO  \
# 0 -2.727623  0.905953 -0.664514 -0.511148 -0.511388 -0.307098 -0.787002
# 1  0.121896 -0.585315  0.154638  0.232161  0.238952 -0.307098  0.236737
# 2 -0.925866  0.116458 -0.678397 -0.754153 -0.643801  2.011315 -0.252844
# 3 -0.201246 -0.673037  0.168522  0.089217  0.040333  1.264463 -0.513555
# 4  0.072935 -0.015124  1.584683  1.561540  1.496876  1.264463  0.236737
#
#          SV         E
# 0  1.532753 -0.348265
# 1  0.312020 -0.540820
# 2 -0.664137 -1.326125
# 3 -0.820689  0.650818
# 4 -1.149165 -0.540820

# %% [markdown]
# # Variance inflation factor:

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features Features
# 0       7.112342        R
# 1      20.237195       AB
# 2      10.114607        H
# 3       3.528059       2B
# 4       3.227808       3B
# 5       8.736960       HR
# 6       3.324550       BB
# 7       2.811546       SO
# 8       1.955254       SB
# 9     200.826177       RA
# 10   2079.420586       ER
# 11   1614.529449      ERA
# 12      2.912414       CG
# 13      3.274913      SHO
# 14      5.914692       SV
# 15      2.341746        E

# %% [markdown]
# VIF values i can say that multicolinearity exists in RA,ER,ERA. So let me drop RA and ER columns to avoid multicolinearity.

# %%
#Droping ER
X = X.drop(["ER"],axis=1)

# %%
X.head(10)
# Out:
#           R        AB         H        2B        3B        HR        BB  \
# 0  0.959398  0.830084  1.723726  1.556538  1.010845 -0.765863 -1.536359
# 1  0.331147 -0.702831 -0.949846  0.201171  1.208917 -0.181389 -0.495021
# 2 -0.274666 -1.100253 -0.088700  1.733325 -0.276617 -0.697101  1.252941
# 3 -1.329231  0.233951 -0.347747 -0.800621 -0.474688 -0.869006 -1.145857
# 4  0.174084  1.255894  2.030708  0.908319  1.704094 -0.353293 -0.197495
# 5  1.856900  0.716535 -0.051906 -0.093474 -1.266972  1.743939  1.643442
# 6  0.712585 -0.447345 -0.553131 -1.625627 -1.167936  1.915843 -0.885522
# 7 -0.835605 -0.447345 -0.310580  0.260100  0.020490  0.196801 -0.550807
# 8  1.497899  1.752672  1.689389  1.202964  0.119526 -0.009484  0.230197
# 9  1.565212 -0.078310  0.349394  0.319029  0.020490  0.368705  0.695081
#
#          SO        SB        RA       ERA        CG       SHO        SV  \
# 0 -2.727623  0.905953 -0.664514 -0.511388 -0.307098 -0.787002  1.532753
# 1  0.121896 -0.585315  0.154638  0.238952 -0.307098  0.236737  0.312020
# 2 -0.925866  0.116458 -0.678397 -0.643801  2.011315 -0.252844 -0.664137
# 3 -0.201246 -0.673037  0.168522  0.040333  1.264463 -0.513555 -0.820689
# 4  0.072935 -0.015124  1.584683  1.496876  1.264463  0.236737 -1.149165
# 5 -0.240414 -0.892341  0.126870  0.150677  0.121871 -2.064039  0.677176
# 6  0.777970 -1.725697  0.057451  0.194815 -1.732896 -0.252844  0.052325
# 7  0.572335  0.160319 -0.650630 -0.489319 -0.870682  0.236737  1.908137
# 8 -1.013995 -0.541454  0.890486  0.768604  0.121871 -0.252844 -0.365006
# 9 -0.181661  0.774370  0.612808  0.614123  0.770649 -0.513555  0.312020
#
#           E
# 0 -0.348265
# 1 -0.540820
# 2 -1.326125
# 3  0.650818
# 4 -0.540820
# 5  0.082858
# 6 -1.588197
# 7  0.237592
# 8  0.383386
# 9  1.554265

# %% [markdown]
# I can see Dependent variables after removing multicolinearity.

# %%
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features Features
# 0       6.069116        R
# 1       7.791456       AB
# 2       9.340727        H
# 3       3.227862       2B
# 4       3.125190       3B
# 5       7.474108       HR
# 6       3.323583       BB
# 7       2.786186       SO
# 8       1.787493       SB
# 9     142.535647       RA
# 10    141.460079      ERA
# 11      2.536866       CG
# 12      3.136960      SHO
# 13      2.630293       SV
# 14      2.272337        E

# %% [markdown]
# Still VIF is high for 2 columns so let me drop ERA.

# %%
#Droping RA
X = X.drop(["ERA"],axis=1)

# %%
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#     vif_Features Features
# 0       6.019438        R
# 1       5.210230       AB
# 2       7.728111        H
# 3       3.165732       2B
# 4       2.981242       3B
# 5       6.168639       HR
# 6       3.053363       BB
# 7       2.287734       SO
# 8       1.773119       SB
# 9       4.759240       RA
# 10      2.522962       CG
# 11      3.121855      SHO
# 12      2.606434       SV
# 13      2.239918        E

# %% [markdown]
# Multicolinearity issue is solved.

# %% [markdown]
# # Splitting the data for training and testing:

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Let find the best random state:

# %%
from sklearn.linear_model import  LinearRegression

LR=LinearRegression()

for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=i)
    LR.fit(x_train,y_train)
    LR_predict_train=LR.predict(x_train)
    LR_predict_test=LR.predict(x_test)
    print(f'At random state{i}, The training accuracy is :-{r2_score(y_train,LR_predict_train)}')
    print(f'At random state{i}, The test accuracy is :-{r2_score(y_test,LR_predict_test)}')
    print('\n')
# Out:
# At random state0, The training accuracy is :-0.9768383015216393
# At random state0, The test accuracy is :-0.49963681285923
#
#
# At random state1, The training accuracy is :-0.9762285427209908
# At random state1, The test accuracy is :-0.18565756675521616
#
#
# At random state2, The training accuracy is :-0.9638255316870881
# At random state2, The test accuracy is :--0.26799016473886206
#
#
# At random state3, The training accuracy is :-0.9677990948927817
# At random state3, The test accuracy is :-0.677669778666176
#
#
# At random state4, The training accuracy is :-0.968056937967967
# At random state4, The test accuracy is :-0.7641316816582832
#
#
# At random state5, The training accuracy is :-0.9612472010423032
# At random state5, The test accuracy is :-0.6051495407607235
#
#
# At random state6, The training accuracy is :-0.9723763056746941
# At random state6, The test accuracy is :-0.7504731543294993
#
#
# At random state7, The training accuracy is :-0.9610245315460935
# At random state7, The test accuracy is :-0.3166954136265213
#
#
# At random state8, The training accuracy is :-0.9718467785099206
# At random state8, The test accuracy is :-0.7189103644396675
#
#
# At random state9, The training accuracy is :-0.9788413708861612
# At random state9, The test accuracy is :-0.6096318438148629
#
#
# At random state10, The training accuracy is :-0.9898377631528767
# At random state10, The test accuracy is :--0.31687653444387576
#
#
# At random state11, The training accuracy is :-0.9672902668384314
# At random state11, The test accuracy is :-0.4159389201823117
#
#
# At random state12, The training accuracy is :-0.9820637271502154
# At random state12, The test accuracy is :-0.4445572049371491
#
#
# At random state13, The training accuracy is :-0.9761821283764095
# At random state13, The test accuracy is :-0.020143013199368287
#
#
# At random state14, The training accuracy is :-0.9544942731905456
# At random state14, The test accuracy is :-0.848060042483881
#
#
# At random state15, The training accuracy is :-0.9864864115138791
# At random state15, The test accuracy is :--0.10346801478325318
#
#
# At random state16, The training accuracy is :-0.9925019011292506
# At random state16, The test accuracy is :--0.9936943668757126
#
#
# At random state17, The training accuracy is :-0.9552281888895084
# At random state17, The test accuracy is :-0.7884803013780877
#
#
# At random state18, The training accuracy is :-0.9752754787824304
# At random state18, The test accuracy is :-0.3648370859745854
#
#
# At random state19, The training accuracy is :-0.963941575294502
# At random state19, The test accuracy is :-0.30974531874977385
#
#
# At random state20, The training accuracy is :-0.976962609330673
# At random state20, The test accuracy is :--0.9902081715053328
#
#
# At random state21, The training accuracy is :-0.9762362874471473
# At random state21, The test accuracy is :--0.08664528828831286
#
#
# At random state22, The training accuracy is :-0.9622663324957269
# At random state22, The test accuracy is :-0.6153820084210004
#
#
# At random state23, The training accuracy is :-0.9842723176772987
# At random state23, The test accuracy is :-0.6348451592098698
#
#
# At random state24, The training accuracy is :-0.9917362835107851
# At random state24, The test accuracy is :--1.8162714187258078
#
#
# At random state25, The training accuracy is :-0.967634384788486
# At random state25, The test accuracy is :--0.06733549086741042
#
#
# At random state26, The training accuracy is :-0.9676515989733351
# At random state26, The test accuracy is :--0.5242151302411948
#
#
# At random state27, The training accuracy is :-0.9738661825825403
# At random state27, The test accuracy is :-0.7800275014950145
#
#
# At random state28, The training accuracy is :-0.9792797129177294
# At random state28, The test accuracy is :-0.5353570492610467
#
#
# At random state29, The training accuracy is :-0.9605523511851897
# At random state29, The test accuracy is :-0.799995804309979
#
#
# At random state30, The training accuracy is :-0.955926168094595
# At random state30, The test accuracy is :-0.8336273702216097
#
#
# At random state31, The training accuracy is :-0.9803613186845543
# At random state31, The test accuracy is :-0.09808350208353922
#
#
# At random state32, The training accuracy is :-0.9727880455575155
# At random state32, The test accuracy is :-0.47410440112693997
#
#
# At random state33, The training accuracy is :-0.9628337653481502
# At random state33, The test accuracy is :-0.6969880726992486
#
#
# At random state34, The training accuracy is :-0.9800176834677644
# At random state34, The test accuracy is :-0.5019062999885204
#
#
# At random state35, The training accuracy is :-0.9747257587155453
# At random state35, The test accuracy is :-0.8131207037783093
#
#
# At random state36, The training accuracy is :-0.9828684858540742
# At random state36, The test accuracy is :--0.14893309380323472
#
#
# At random state37, The training accuracy is :-0.9781033291470543
# At random state37, The test accuracy is :--0.11392503266750453
#
#
# At random state38, The training accuracy is :-0.9629822858027242
# At random state38, The test accuracy is :-0.46896632024258134
#
#
# At random state39, The training accuracy is :-0.9819482068994164
# At random state39, The test accuracy is :--0.0022735853621196345
#
#
# At random state40, The training accuracy is :-0.986064159282848
# At random state40, The test accuracy is :--0.19765376629023423
#
#
# At random state41, The training accuracy is :-0.9545829293375787
# At random state41, The test accuracy is :-0.8088713012655714
#
#
# At random state42, The training accuracy is :-0.9662606992561762
# At random state42, The test accuracy is :-0.577841959841173
#
#
# At random state43, The training accuracy is :-0.9860408462105144
# At random state43, The test accuracy is :--5.543286250837872
#
#
# At random state44, The training accuracy is :-0.9845298133365212
# At random state44, The test accuracy is :-0.07129828665255478
#
#
# At random state45, The training accuracy is :-0.9811583645973044
# At random state45, The test accuracy is :-0.20024380439536615
#
#
# At random state46, The training accuracy is :-0.9673430419463019
# At random state46, The test accuracy is :--0.27772042176118195
#
#
# At random state47, The training accuracy is :-0.971497975831828
# At random state47, The test accuracy is :--0.29213095983464155
#
#
# At random state48, The training accuracy is :-0.9890551853764096
# At random state48, The test accuracy is :--0.7196013645554276
#
#
# At random state49, The training accuracy is :-0.9835334893607127
# At random state49, The test accuracy is :--0.1679675846809774
#
#
# At random state50, The training accuracy is :-0.9537647229539135
# At random state50, The test accuracy is :-0.8316780990025265
#
#
# At random state51, The training accuracy is :-0.9707793197804685
# At random state51, The test accuracy is :-0.7376571558186891
#
#
# At random state52, The training accuracy is :-0.9891902525765096
# At random state52, The test accuracy is :--0.12942400087228667
#
#
# At random state53, The training accuracy is :-0.9762241207879092
# At random state53, The test accuracy is :-0.44983422215569957
#
#
# At random state54, The training accuracy is :-0.9761432125804467
# At random state54, The test accuracy is :--0.05304591605201803
#
#
# At random state55, The training accuracy is :-0.9614974630254448
# At random state55, The test accuracy is :-0.3802135617856649
#
#
# At random state56, The training accuracy is :-0.9749201446052391
# At random state56, The test accuracy is :-0.7255781232872811
#
#
# At random state57, The training accuracy is :-0.9653412168780406
# At random state57, The test accuracy is :-0.7592380863729902
#
#
# At random state58, The training accuracy is :-0.9863597768390849
# At random state58, The test accuracy is :-0.6828354364707114
#
#
# At random state59, The training accuracy is :-0.9709841465989217
# At random state59, The test accuracy is :-0.8210088959364735
#
#
# At random state60, The training accuracy is :-0.98950428980896
# At random state60, The test accuracy is :-0.11806917325109356
#
#
# At random state61, The training accuracy is :-0.9743321263697652
# At random state61, The test accuracy is :-0.7155382222230904
#
#
# At random state62, The training accuracy is :-0.9813232093230445
# At random state62, The test accuracy is :-0.7939046316735211
#
#
# At random state63, The training accuracy is :-0.9820000911158873
# At random state63, The test accuracy is :-0.5977506629877025
#
#
# At random state64, The training accuracy is :-0.9570117243236274
# At random state64, The test accuracy is :-0.7484439773829747
#
#
# At random state65, The training accuracy is :-0.9785915941789564
# At random state65, The test accuracy is :-0.3888262523792331
#
#
# At random state66, The training accuracy is :-0.95567421882885
# At random state66, The test accuracy is :-0.6270406623530123
#
#
# At random state67, The training accuracy is :-0.9598461778869003
# At random state67, The test accuracy is :-0.6202987353533924
#
#
# At random state68, The training accuracy is :-0.9608625145030375
# At random state68, The test accuracy is :-0.3338504225973632
#
#
# At random state69, The training accuracy is :-0.9709265741212019
# At random state69, The test accuracy is :-0.3579220950493074
#
#
# At random state70, The training accuracy is :-0.9677036948240955
# At random state70, The test accuracy is :-0.4750062769038973
#
#
# At random state71, The training accuracy is :-0.9908534857219358
# At random state71, The test accuracy is :--1.4433267148551598
#
#
# At random state72, The training accuracy is :-0.9730022203302446
# At random state72, The test accuracy is :--1.9267584512627005
#
#
# At random state73, The training accuracy is :-0.9861714764983074
# At random state73, The test accuracy is :-0.245422592726105
#
#
# At random state74, The training accuracy is :-0.9672053986263304
# At random state74, The test accuracy is :-0.37386023970732374
#
#
# At random state75, The training accuracy is :-0.965200538698459
# At random state75, The test accuracy is :-0.4396734254247918
#
#
# At random state76, The training accuracy is :-0.9697686213170073
# At random state76, The test accuracy is :-0.6484848363278877
#
#
# At random state77, The training accuracy is :-0.9581167435043935
# At random state77, The test accuracy is :-0.8079170867573303
#
#
# At random state78, The training accuracy is :-0.962399647050826
# At random state78, The test accuracy is :-0.1946336518039481
#
#
# At random state79, The training accuracy is :-0.9747902605630038
# At random state79, The test accuracy is :-0.6949327320309335
#
#
# At random state80, The training accuracy is :-0.9697742317687917
# At random state80, The test accuracy is :-0.7185334711021878
#
#
# At random state81, The training accuracy is :-0.972705393693507
# At random state81, The test accuracy is :-0.8185938162515088
#
#
# At random state82, The training accuracy is :-0.979871253944829
# At random state82, The test accuracy is :-0.4567799500535028
# At random state83, The training accuracy is :-0.9756317606315614
# At random state83, The test accuracy is :-0.28315423815791374
#
#
# At random state84, The training accuracy is :-0.9828111868130212
# At random state84, The test accuracy is :-0.23591372065271055
#
#
# At random state85, The training accuracy is :-0.9669327510611356
# At random state85, The test accuracy is :-0.24617817938123387
#
#
# At random state86, The training accuracy is :-0.9676054527656348
# At random state86, The test accuracy is :--1.0577215005047824
#
#
# At random state87, The training accuracy is :-0.966826745082624
# At random state87, The test accuracy is :-0.11515984841524751
#
#
# At random state88, The training accuracy is :-0.992288736669312
# At random state88, The test accuracy is :--1.730503227993292
#
#
# At random state89, The training accuracy is :-0.9701384384212995
# At random state89, The test accuracy is :-0.5944959477898806
#
#
# At random state90, The training accuracy is :-0.966839570157248
# At random state90, The test accuracy is :-0.5649215655468443
#
#
# At random state91, The training accuracy is :-0.9844104607034702
# At random state91, The test accuracy is :-0.3706838329676141
#
#
# At random state92, The training accuracy is :-0.9876320209564958
# At random state92, The test accuracy is :-0.42566467965693267
#
#
# At random state93, The training accuracy is :-0.9749450302178474
# At random state93, The test accuracy is :--0.41905412520620877
#
#
# At random state94, The training accuracy is :-0.9792637837645165
# At random state94, The test accuracy is :--0.6159768201216846
#
#
# At random state95, The training accuracy is :-0.9718301805648831
# At random state95, The test accuracy is :-0.41294016146225343
#
#
# At random state96, The training accuracy is :-0.9942908486324531
# At random state96, The test accuracy is :--1.3890191407424437
#
#
# At random state97, The training accuracy is :-0.9600175489916121
# At random state97, The test accuracy is :-0.6801134423165955
#
#
# At random state98, The training accuracy is :-0.9930524310322554
# At random state98, The test accuracy is :--2.7725795052050826
#
#
# At random state99, The training accuracy is :-0.9633011594527382
# At random state99, The test accuracy is :-0.8004187639449175

# %% [markdown]
# I can see random state=99 giving highest accuracy,choosing that as random state.

# %%
#Splitting the data into 78% training and 22% testing

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=99)

# %%
x_train.shape
# Out:
# (22, 16)

# %%
y_train.shape
# Out:
# (22,)

# %%
x_test.shape
# Out:
# (7, 16)

# %%
y_test.shape
# Out:
# (7,)

# %% [markdown]
# # Model Building:

# %% [markdown]
# # Regression Algorithms:

# %%
#Importing necessary libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import SGDRegressor 
from sklearn.metrics import classification_report
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import BaggingRegressor
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso,Ridge

# %% [markdown]
# # 1)Linear Regression:

# %%
from sklearn.linear_model import LinearRegression

LR=LinearRegression()
LR.fit(x_train,y_train)
print(LR.score(x_train,y_train))
LR_predict=LR.predict(x_test)
# Out:
# 0.9633011594527382

# %%
print('MSE:',mean_squared_error(LR_predict,y_test))
print('MAE:',mean_absolute_error(LR_predict,y_test))
print('r2_score:',r2_score(LR_predict,y_test))
# Out:
# MSE: 27.07787872028957
# MAE: 4.999072397569579
# r2_score: 0.8702723798742851

# %% [markdown]
# LR is giving me 88% r2_score.

# %% [markdown]
# # 2)SGD:

# %%
from sklearn.linear_model import SGDRegressor
sgd=SGDRegressor()
sgd.fit(x_train,y_train)
pred=sgd.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('mae:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: -1.7580424767465023e+31
# mae: 2.3851972215123978e+33
# mae: 4.8795381820310184e+16
# rmse: 4.883848095009096e+16

# %% [markdown]
# SGD is giving me 90% r2_score.

# %% [markdown]
# # 3)Lasso Regressor:

# %%
parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
ls=Lasso()
Z=GridSearchCV(ls,parameters)
Z.fit(x_train,y_train)
print(Z.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
pred=ls.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('mse:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.8162585359689933
# mse: 24.928841895472097
# mae: 4.824282278813727
# rmse: 4.992879118852378

# %% [markdown]
# Lasso is giving me 90%r2_score.

# %% [markdown]
# # 4)Ridge Regressor:

# %%
parameters={'alpha':[0.001,0.01,0.1,1,10],'solver':['auto','svd','cholesky','lsqr','sparse_cg','sag','saga']}
rd=Ridge()
Z1=GridSearchCV(rd,parameters)
Z1.fit(x_train,y_train)
print(Z1.best_params_)
# Out:
# {'alpha': 10, 'solver': 'saga'}

# %%
rd=Ridge(alpha=10,solver='lsqr')
rd.fit(x_train,y_train)
pred=rd.predict(x_test)
print('R2_score:',r2_score(y_test,pred))
print('mse:',metrics.mean_squared_error(y_test,pred))
print('mae:',metrics.mean_absolute_error(y_test,pred))
print('rmse:',np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_score: 0.8412546853173765
# mse: 21.537527592042476
# mae: 4.381776173953869
# rmse: 4.64085418775924

# %% [markdown]
# Ridge is giving 76%r2_score.

# %% [markdown]
# # Cross Validation:

# %%
from sklearn.model_selection import cross_val_score

np.random.seed(10)
def rmse_cv(model,x,y):
    rmse =-(cross_val_score(model,x,y, scoring='neg_mean_squared_error', cv=10))
    return(rmse)

models = [LinearRegression(),
         Ridge(),
         SVR(kernel='linear'),
         SVR(kernel='poly'),
         SVR(kernel='rbf'),
         RandomForestRegressor(),
         DecisionTreeRegressor(),
         GradientBoostingRegressor(),]

names = ['LR','R','svr','svr_p','svr_r','RF','DTR','GBR']

for model,name in zip(models,names):
    score = rmse_cv(model,x,y)
    print("{}   : {:.6f}, {:4f}".format(name,score.mean(),score.std()))
# Out:
# LR   : 33.227142, 22.206678
# R   : 32.549049, 32.609656
# svr   : 54.292689, 31.284378
# svr_p   : 111.891643, 79.768934
# svr_r   : 112.275451, 79.777668
# RF   : 39.864027, 24.023091
# DTR   : 70.216667, 45.490539
# GBR   : 47.569624, 31.099844

# %% [markdown]
# According to all metrics score selecting the linearRegression as final model

# %% [markdown]
# # Hyper Parameter Tuning:

# %%
#Importing necessary libraries
from sklearn.model_selection import GridSearchCV

# %%
parameter = {'alpha':[0.01,0.1,1.0,10.26],
            'selection':['cyclic','random'],
            'max_iter':[2,4,6,8,10],
            'tol':[100,1000],
            'fit_intercept':['bool']}

# %%
GVC=GridSearchCV(Lasso(),parameter,cv=5)

# %%
GVC.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1.0, 10.26],
#                          'fit_intercept': ['bool'],
#                          'max_iter': [2, 4, 6, 8, 10],
#                          'selection': ['cyclic', 'random'],
#                          'tol': [100, 1000]})

# %%
GVC.best_params_
# Out:
# {'alpha': 0.1,
#  'fit_intercept': 'bool',
#  'max_iter': 2,
#  'selection': 'random',
#  'tol': 1000}

# %% [markdown]
# I can see best parameters.

# %%
Final_mod=Lasso(alpha=1.0, fit_intercept="bool", max_iter=4, selection="random", tol=1000)
Final_mod.fit(x_train,y_train)
pred=Final_mod.predict(x_test)
print('R2_Score:',r2_score(y_test,pred)*100)
print('mean_squared_error:',metrics.mean_squared_error(y_test,pred))
print('mean_absolute_error:',metrics.mean_absolute_error(y_test,pred))
print("RMSE value:",np.sqrt(metrics.mean_squared_error(y_test,pred)))
# Out:
# R2_Score: 79.48387716584048
# mean_squared_error: 27.83493563295764
# mean_absolute_error: 4.335455222041607
# RMSE value: 5.275882450638721

# %% [markdown]
# After tuning i got 79.48% accuracy which is goo

# %% [markdown]
# # Saving the model:

# %%
#Saving the model using .pkl
import joblib
joblib.dump(Final_mod,"BaseBallCaseStudy.pkl")
# Out:
# ['BaseBallCaseStudy.pkl']

# %% [markdown]
# I have saved my model using joblib.

# %% [markdown]
# # Predictions:

# %%
#Loading the saved model
model=joblib.load("BaseballCaseStudy.pkl")

#Prediction
prediction = model.predict(x_test)
prediction
# Out:
# array([69.58640733, 67.11525668, 85.45311838, 79.89227939, 85.81429738,
#        88.93161129, 83.67532456])

# %% [markdown]
# These are predicted values

# %%
pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
# Out:
#                    0          1          2          3          4          5  \
# Predicted  69.586407  67.115257  85.453118  79.892279  85.814297  88.931611
# Original   67.000000  63.000000  97.000000  76.000000  83.000000  92.000000
#
#                    6
# Predicted  83.675325
# Original   86.000000

# %% [markdown]
# Both original and predicted values are almost equal.

# %% [markdown]
# # COMPLETED THE BASEBALLCASE STUDY
